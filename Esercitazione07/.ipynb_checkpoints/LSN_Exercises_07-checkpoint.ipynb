# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 7</span>

# %% [markdown]
# ### Exercise 07.1
#
# Use the Monte Carlo NVT code we have provided to <span style="color:red">print out instantaneous values of potential energy per particle, $U/N$, and pressure, $P$, along **equilibrated** Monte Carlo simulations</span> (of $M=5\times 10^5$ MC steps and where the Metropolis acceptance ratio has been fixed approximately to 50%) in the following thermodynamic conditions:
# - solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# - liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# - gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)

# %% [markdown]
# 1. <span style="color:red">Once this data has been produced, compute and make pictures with a python script of the autocorrelation functions of $U/N$ and $P$ to approximately estimate how large the blocks in your simulations should be.
# 2. Use the same data to study, with a python script, the estimation of the statistical uncertainties of the expectation value of $U/N$ and $P$ for different size of the blocks in the data blocking technique, from $L=M/N=10$ to $L=5\times 10^3$, being $N$ the number of blocks. <span style="color:red">Make pictures of these statistical uncertainties as a function of $L$.</span> What you observe in the statistical uncertainties after that the block size is large enough (from the point of view of the data blocking technique)?

# %% [markdown]
# #### Monte Carlo NVT
#
# Utilizzo il codice per generare $5 \cdot 10^5$ campioni di energia e pressione per ciascuna delle tre fasi. Per il solido e il liquido imposto lo step del Metropolis in modo da ottenere un'accettazione di $\approx 50\%$, mentre per il gas scelgo uno step pari alla larghezza del box di simulazione, che però non consente di abbassare l'accettazione al di sotto del $60 \%$.
#
# Come configurazione di partenza utilizzo un cristallo perfetto FCC e impongo il numero di passi necessari per l'equilibrazione a seconda della fase: $100$ per il solido, $300$ per il liquido e $1000$ per il gas.
#
# Utilizzo i dati generati per calcolare la funzione di autocorrelazione, valutata per numero di step in $[0, n_{\mathrm{max}}]$, con $n_{\mathrm{max}}=200$ per il solido, $n_{\mathrm{max}}=400$ per il liquido e $n_{\mathrm{max}}=50$ per il gas.
# Invece per calcolare l'errore in funzione della taglia del blocco utilizzo punti distanziati di $20$ l'intervallo $[10, 5000]$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_steps_s, AC_U_solid, AC_P_solid = np.loadtxt("Es07.1/Analisi/AC_solid.dat", usecols=(0,1, 2), delimiter=' ', unpack=True)
n_steps_l, AC_U_liquid, AC_P_liquid = np.loadtxt("Es07.1/Analisi/AC_liquid.dat", usecols=(0,1, 2), delimiter=' ', unpack=True)
n_steps_g, AC_U_gas, AC_P_gas = np.loadtxt("Es07.1/Analisi/AC_gas.dat", usecols=(0,1, 2), delimiter=' ', unpack=True)



fig = plt.figure(figsize = (15,5))
plt.suptitle('Fase solida', size=20)

plt.subplot(1, 2, 1)    

plt.plot(n_steps_s, AC_U_solid)
plt.xlabel("t [steps]")
plt.ylabel("AC")
plt.title("Funzione di autocorrelazione per U/N")
plt.grid(True)

plt.subplot(1, 2, 2)   

plt.plot(n_steps_s, AC_P_solid)
plt.xlabel("t [steps]")
plt.ylabel("AC")
plt.title("Funzione di autocorrelazione per P")
plt.grid(True)

plt.subplots_adjust(wspace=0.3, hspace=0.3)



fig = plt.figure(figsize = (15,5))
plt.suptitle('Fase liquida', size=20)

plt.subplot(1, 2, 1)    

plt.plot(n_steps_l, AC_U_liquid)
plt.xlabel("t [steps]")
plt.ylabel("AC")
plt.title("Funzione di autocorrelazione per U/N")
plt.grid(True)

plt.subplot(1, 2, 2)   

plt.plot(n_steps_l, AC_P_liquid)
plt.xlabel("t [steps]")
plt.ylabel("AC")
plt.title("Funzione di autocorrelazione per P")
plt.grid(True)

plt.subplots_adjust(wspace=0.3, hspace=0.3)



fig = plt.figure(figsize = (15,5))
plt.suptitle('Fase gassosa', size=20)

plt.subplot(1, 2, 1)    

plt.plot(n_steps_g, AC_U_gas)
plt.xlabel("t [steps]")
plt.ylabel("AC")
plt.title("Funzione di autocorrelazione per U/N")
plt.grid(True)

plt.subplot(1, 2, 2)   

plt.plot(n_steps_g, AC_P_gas)
plt.xlabel("t [steps]")
plt.ylabel("AC")
plt.title("Funzione di autocorrelazione per P")
plt.grid(True)

plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# Si osserva che le configurazioni del gas si scorrelano molto velocemente, mentre invece il solido e il liquido perdono le correlazioni dopo un numero maggiore di passi.

# %%
Ls_s, err_U_solid, err_P_solid = np.loadtxt("Es07.1/Analisi/err_solid.dat", usecols=(0,1, 2), delimiter=' ', unpack=True)
Ls_l, err_U_liquid, err_P_liquid = np.loadtxt("Es07.1/Analisi/err_liquid.dat", usecols=(0,1, 2), delimiter=' ', unpack=True)
Ls_g, err_U_gas, err_P_gas = np.loadtxt("Es07.1/Analisi/err_gas.dat", usecols=(0,1, 2), delimiter=' ', unpack=True)



fig = plt.figure(figsize = (15,6))
plt.suptitle('Fase solida', size=20)


plt.subplot(1, 2, 1)    

plt.plot(Ls_s, err_U_solid + 0.002, label='Energia + $2 \cdot 10^{-3}$')
plt.plot(Ls_s, err_P_solid, label='Pressione')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.xlabel("# passi per blocco", size=12)
plt.ylabel("$\sigma$", size=12)
plt.title("Errore vs numero di passi per blocco", size=14)
plt.grid(True)
plt.legend(loc='lower center', ncol=2)

plt.subplot(2, 2, 2)   

plt.plot(Ls_s, err_U_solid)
plt.xscale('log')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel("$\sigma_U$")
plt.title("Errore di U/N (scala logaritmica)", size=14)
plt.grid(True)

plt.subplot(2, 2, 4)   

plt.plot(Ls_s, err_P_solid, color='tab:orange')
plt.xscale('log')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.xlabel("# passi per blocco", size=12)
plt.ylabel("$\sigma_P$")
plt.title("Errore di P (scala logaritmica)", size=14)
plt.grid(True)

plt.subplots_adjust(wspace=0.3, hspace=0.3)




fig = plt.figure(figsize = (15,6))
plt.suptitle('Fase liquida', size=20)


plt.subplot(1, 2, 1)    

plt.plot(Ls_l, err_U_liquid + 0.002, label='Energia + $2 \cdot 10^{-3}$')
plt.plot(Ls_l, err_P_liquid, label='Pressione')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.xlabel("# passi per blocco", size=12)
plt.ylabel("$\sigma$", size=12)
plt.title("Errore vs numero di passi per blocco", size=14)
plt.grid(True)
plt.legend(loc='lower center', ncol=2)

plt.subplot(2, 2, 2)   

plt.plot(Ls_l, err_U_liquid)
plt.xscale('log')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel("$\sigma_U$")
plt.title("Errore di U/N (scala logaritmica)", size=14)
plt.grid(True)

plt.subplot(2, 2, 4)   

plt.plot(Ls_l, err_P_liquid, color='tab:orange')
plt.xscale('log')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.xlabel("# passi per blocco", size=12)
plt.ylabel("$\sigma_P$")
plt.title("Errore di P (scala logaritmica)", size=14)
plt.grid(True)

plt.subplots_adjust(wspace=0.3, hspace=0.3)




fig = plt.figure(figsize = (15,6))
plt.suptitle('Fase gassosa', size=20)


plt.subplot(1, 2, 1)    

plt.plot(Ls_g, err_U_gas, label='Energia')
plt.plot(Ls_g, err_P_gas + 0.00015, label='Pressione + $1.5 \cdot 10^{-4}$')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.xlabel("# passi per blocco", size=12)
plt.ylabel("$\sigma$", size=12)
plt.title("Errore vs numero di passi per blocco", size=14)
plt.grid(True)
plt.legend(loc='lower center', ncol=2)

plt.subplot(2, 2, 2)   

plt.plot(Ls_g, err_U_gas)
plt.xscale('log')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.ylabel("$\sigma_U$")
plt.title("Errore di U/N (scala logaritmica)", size=14)
plt.grid(True)

plt.subplot(2, 2, 4)   

plt.plot(Ls_g, err_P_gas, color='tab:orange')
plt.xscale('log')
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))
plt.xlabel("# passi per blocco", size=12)
plt.ylabel("$\sigma_P$")
plt.title("Errore di P (scala logaritmica)", size=14)
plt.grid(True)

plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# A sinistra vengono riportati gli errori di energia e pressione in funzione dei passi per blocco. Una delle due curve è traslata verticalmente per poterla confrontare meglio all'altra.
# A destra vengono riportate le stesse curve con l'asse $x$ in scala logaritmica, per evidenziare meglio la crescita iniziale e vedere dopo quanti passi l'errore rimane costante.
#
# Per la fase solida l'errore satura dopo circa $400$ passi, mentre per il liquido dopo circa $1000$ passi. Per il gas si hanno oscillazioni molto irregolari e gli errori sono su una scala più piccola. Si osserva che il trend crescente si arresta dopo circa $600$ passi.

# %% [markdown]
# ### Exercise 07.2
#
# <span style="color:red">Include the calculation of the radial distribution function, $g(r)$, as a function of the radial distance $r$ among particles, with $r \in \left[ 0; L/2\right]$ inside the Monte Carlo NVT code</span> we have provided: average value of $g(r)$ in each block (with output in the file: output.gofr.0), final average value of $g(r)$ with statistical uncertainties (with output in the file: output.gave.0).

# %% [markdown]
# ### Exercise 07.3
#
# <span style="color:red">Include the calculation of the radial distribution function, $g(r)$, inside the previously used Molecular Dynamics code</span>.

# %% [markdown]
# ### Exercise 07.4
#
# By means of your upgraded MC code, equilibrate and <span style="color:red">perform MC NVT simulations via a Lennard-Jones model</span> of Argon ($\sigma = 0.34$ nm, $\epsilon/k_B = 120$ K, $m=39.948$ amu) in the following conditions:
# 1. solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# 2. liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# 3. gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)
#
# show in pictures the obtained average values and uncertainties for the potential energy per particle, $U/N$, the pressure $P$ and the radial distribution function $g(r)$ in SI units ... <span style="color:red"> and compare your MC results for the radial distribution function, $g(r)$, with those obtained with Molecular Dynamics NVE simulations in similar thermodynamic conditions.</span>

# %% [markdown]
# #### Simulazioni Argon
#
# Simulo le tre differenti fasi (solida, liquida e gas) dopo averle opportunamente equilibrate partendo da una configurazione iniziale di cristallo FCC perfetto.
# Per evitare configurazioni correlate utilizzo il metodo della media a blocchi, scegliendo una taglia sufficientemente grande per evitare di sottostimare l'errore.
#
# Eseguo anche la simulazione NVE per calcolare la funzione $g(r)$ da confrontare con quella ottenuta con il metodo Monte CArlo. Per queste simulazioni utilizzo come configurazioni di partenza quelle equilibrate per la quarta esercitazione.
#
# Il codice utilizza le unità di Lennard-Jones. Per passare a unità del sistema internazionale è necessario tenere conto delle seguente relazioni per l'energia, la pressione e il raggio:
#
#
# $$ E = \epsilon E^* $$
#
# $$ P = \frac{\epsilon}{\sigma^3} P^* $$
#
# $$ r = \sigma r^* $$

# %%
##### fattori di conversione #####

kB = 1.380649 * 10**-23  #[J K^-1]
T2SI = 120               #energia da unità di LJ a SI [K]
E2SI =  T2SI*kB          #energia da unità di LJ a SI [J] (=epsilon)

sigma_nm=0.34            #sigma in nm
sigma=sigma_nm*10**-9    #sigma in m

P2SI=E2SI*sigma**-3      #pressione da unità di LJ a SI [J m^-3]

r2SI=sigma_nm

# %% [markdown]
# ### Fase solida
#
# Simulo un sistema a $\rho^\star = 1.1$, $T^\star = 0.8$ e $r_c = 2.2$. Per entrambe le simulazioni uso $100$ blocchi, ciascuno che consiste di $1000$ step. Nel caso NVE la misura è effettuata ogni $10$ passi.

# %%
N, sum_prog_epot, err_prog_epot = np.loadtxt("Es07.4/Solid/Epot.dat", usecols=(0,2,3), delimiter=None, unpack=True)
N, sum_prog_pres, err_prog_pres = np.loadtxt("Es07.4/Solid/Pres.dat", usecols=(0,2,3), delimiter=None, unpack=True)
r, g_NVT, err_g_NVT = np.loadtxt("Es07.4/Solid/g_ave_NVT.dat", usecols=(0,1,2), delimiter=None, unpack=True)
r, g_NVE, err_g_NVE = np.loadtxt("Es07.4/Solid/g_ave_NVE.dat", usecols=(0,1,2), delimiter=None, unpack=True)


fig = plt.figure(figsize = (15,12))
plt.suptitle('Fase solida', size=20)

plt.subplot(2, 2, 1)
plt.errorbar(N,sum_prog_epot*E2SI, yerr=err_prog_epot*E2SI)
plt.xlabel('# steps', size=12)
plt.ylabel('$E_{pot}$ [$ \ J$]', size=15)
plt.title('Energia potenziale', size=18)
plt.grid(True)


plt.subplot(2, 2, 2)
plt.errorbar(N,sum_prog_pres*P2SI, yerr=err_prog_pres*P2SI)
plt.xlabel('# steps', size=15)
plt.ylabel('$P$ [$\ J m^{-3}$]', size=15)
plt.title('Pressione', size=18)
plt.grid(True)


plt.subplot(2, 1, 2)

plt.errorbar(r*r2SI, g_NVT, yerr=err_g_NVT, label='MonteCarlo NVT')
plt.errorbar(r*r2SI, g_NVE, yerr=err_g_NVE, label='MolDyn NVE')
plt.xlabel('$r$ [nm]', size=15)
plt.ylabel('$g(r)$', size=15)
plt.title('Funzione di distribuzione radiale (NVT)', size=18)
plt.grid(True)
plt.legend()


plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# ### Fase liquida
#
# Simulo un sistema a $\rho^\star = 0.8$, $T^\star = 1.1$ e $r_c = 2.5$. Per entrambe le simulazioni uso $100$ blocchi, ciascuno di $1000$ step nel caso NVE (con misura ogni $10$) e di $2000$ nel caso NVT.

# %%
N, sum_prog_epot, err_prog_epot = np.loadtxt("Es07.4/Liquid/Epot.dat", usecols=(0,2,3), delimiter=None, unpack=True)
N, sum_prog_pres, err_prog_pres = np.loadtxt("Es07.4/Liquid/Pres.dat", usecols=(0,2,3), delimiter=None, unpack=True)
r, g_NVT, err_g_NVT = np.loadtxt("Es07.4/Liquid/g_ave_NVT.dat", usecols=(0,1,2), delimiter=None, unpack=True)
r, g_NVE, err_g_NVE = np.loadtxt("Es07.4/Liquid/g_ave_NVE.dat", usecols=(0,1,2), delimiter=None, unpack=True)


fig = plt.figure(figsize = (15,12))
plt.suptitle('Fase liquida', size=20)

plt.subplot(2, 2, 1)
plt.errorbar(N,sum_prog_epot*E2SI, yerr=err_prog_epot*E2SI)
plt.xlabel('# steps', size=12)
plt.ylabel('$E_{pot}$ [$ \ J$]', size=15)
plt.title('Energia potenziale', size=18)
plt.grid(True)


plt.subplot(2, 2, 2)
plt.errorbar(N,sum_prog_pres*P2SI, yerr=err_prog_pres*P2SI)
plt.xlabel('# steps', size=15)
plt.ylabel('$P$ [$\ J m^{-3}$]', size=15)
plt.title('Pressione', size=18)
plt.grid(True)


plt.subplot(2, 1, 2)

plt.errorbar(r*r2SI, g_NVT, yerr=err_g_NVT, label='MonteCarlo NVT')
plt.errorbar(r*r2SI, g_NVE, yerr=err_g_NVE, label='MolDyn NVE')
plt.xlabel('$r$ [nm]', size=15)
plt.ylabel('$g(r)$', size=15)
plt.title('Funzione di distribuzione radiale (NVT)', size=18)
plt.grid(True)
plt.legend()


plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# ### Fase gassosa
#
#
# Simulo un sistema a $\rho^\star = 0.05$, $T^\star = 1.2$ e $r_c = 5.0$. Per entrambe le simulazioni uso $100$ blocchi, ciascuno che consiste di $1000$ step. Nel caso NVE la misura è effettuata ogni $10$ passi.

# %%
N, sum_prog_epot, err_prog_epot = np.loadtxt("Es07.4/Gas/Epot.dat", usecols=(0,2,3), delimiter=None, unpack=True)
N, sum_prog_pres, err_prog_pres = np.loadtxt("Es07.4/Gas/Pres.dat", usecols=(0,2,3), delimiter=None, unpack=True)
r, g_NVT, err_g_NVT = np.loadtxt("Es07.4/Gas/g_ave_NVT.dat", usecols=(0,1,2), delimiter=None, unpack=True)
r, g_NVE, err_g_NVE = np.loadtxt("Es07.4/Gas/g_ave_NVE.dat", usecols=(0,1,2), delimiter=None, unpack=True)


fig = plt.figure(figsize = (15,12))
plt.suptitle('Fase gassosa', size=20)

plt.subplot(2, 2, 1)
plt.errorbar(N,sum_prog_epot*E2SI, yerr=err_prog_epot*E2SI)
plt.xlabel('# steps', size=12)
plt.ylabel('$E_{pot}$ [$ \ J$]', size=15)
plt.title('Energia potenziale', size=18)
plt.grid(True)


plt.subplot(2, 2, 2)
plt.errorbar(N,sum_prog_pres*P2SI, yerr=err_prog_pres*P2SI)
plt.xlabel('# steps', size=15)
plt.ylabel('$P$ [$\ J m^{-3}$]', size=15)
plt.title('Pressione', size=18)
plt.grid(True)


plt.subplot(2, 1, 2)

plt.errorbar(r*r2SI, g_NVT, yerr=err_g_NVT, label='MonteCarlo NVT')
plt.errorbar(r*r2SI, g_NVE, yerr=err_g_NVE, label='MolDyn NVE')
plt.xlabel('$r$ [nm]', size=15)
plt.ylabel('$g(r)$', size=15)
plt.title('Funzione di distribuzione radiale', size=18)
plt.grid(True)
plt.legend()


plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# Per tutte e tre le fasi le stime di energia potenziale e pressione convergono a un valore finito, con incertezze e fluttuazioni sempre minori al crescere dei blocchi.
#
# Per tutte le fasi le funzioni di distribuzione radiale calcolate con entrambi i metodi seguono lo stesso andamento.
