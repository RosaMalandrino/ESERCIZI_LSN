# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 6</span>

# %% [markdown]
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following I will assume units such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50

# %%
def f_energy(T):
    beta = 1/T
    th = np.tanh(J/T)
    thN= th**Ns   
    ch = 1/th
    
    return -J*( th + ch*thN )/( 1 + thN )

e=np.array([f_energy(temp) for temp in T])

plt.plot(T, e)
plt.title('Ising 1D, internal energy')
plt.xlabel('T')
plt.ylabel('U/N')
plt.show()

# %% [markdown]
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$

# %%
def f_heat(T):
    beta = 1/T
    th = np.tanh(J/T)
    thN= th**Ns
    ch = 1/th
    
    return ((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)

heat=np.array([f_heat(temp) for temp in T])

plt.plot(T, heat)
plt.title('Ising 1D, Heat capacity')
plt.xlabel('T')
plt.ylabel('C')
plt.show()

# %% [markdown]
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$

# %%
h=0.02 #external field

def f_mag(T, h):
    b = 1/T
    l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
    l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
    Z = l1**Ns + l2**Ns
    
    return (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)


M=np.array([f_mag(temp, h) for temp in T])
    
plt.plot(T, M)
plt.title('Ising 1D, magnetization M with h = 0.02')
plt.xlabel('T')
plt.ylabel('$M$')
plt.show()

# %% [markdown]
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$

# %%
def f_chi(T):
    
    beta = 1/T
    th = np.tanh(J/T)
    thN= th**Ns
    
    return beta*np.exp(2*beta*J)*(1-thN)/(1+thN)


X=np.array([f_chi(temp) for temp in T])

plt.plot(T, X)
plt.title('Ising 1D, Susceptibility')
plt.xlabel('T')
plt.ylabel('$\chi$')
plt.show()

# %% [markdown]
# ### Exercise 06.1
#
# Complete the C++ code to simulate 1D Ising model (It is available on the Ariel web site of this Laboratory) with
# - the Metropolis sampling algorithm and
# - the Gibbs sampling algorithm
#
# to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$,
# adding also the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# - <span style="color:red">Show pictures of your estimations of $U(N,T)$, $C(N,T)$, $\chi(N,T)$, $M(N,T,h=0.02)$ and their uncertainties</span> obtained with a large number of *MC steps* (e.g. $M\ge 10^5$) compared with the exact curves. In the same picture show your results obtained with both sampling methods, Metropolis and Gibbs.
#
# A Monte Carlo step will consist in trying to flip one time all the spins of the system. Do not forget to equilibrate your simulations and to use blocking average with blocks large enough.

# %% [markdown]
# #### Ising 1D
#
# Simulo il modello di Ising monodimensionale con $N=50$ spin, utilizzando gli algoritmi di Metropolis e di Gibbs.
#
# Il numero di interazioni necessarie per l'equilibrazione dipende dalla temperatura e dalla configurazione iniziale. In generale partendo da spin orientati in maniera casuale ci vogliono pochi step ($n_{step}<200$) per raggiungere l'equilibrio per temperature alte, mentre a $T$ più basse sono necessari più passi (conservativamente $n_{step}<1000$).
# Invece partendo da una temperatura alta e abbassandola gradualmente è possibile sfruttare la configurazione finale ottenuta nella simulazione precedente come punto di partenza. In questo modo il numero di step necessario ad equilibrare è sempre basso ($n_{step}<100$).
#
# Ad ogni iterazione seleziono casualmente uno degli $N$ spin. Nel caso di Metropolis considero la differenza tra l'energia precedente e quella proposta dopo aver invertito il segno dello spin selezionato. La nuova configurazione viene accettata o rifiutata a seconda delle probabilità secondo il Metropolis. Nel caso di Gibbs si calcola la differenza tra l'energia quando lo spin è up rispetto a quando è down, indipendente da quale sia la configurazione attuale. Si estrae la nuova configurazione a seconda della sua probabilità rispetto all'altra. La mossa ad ogni iterazione consiste nel ripetere questa operazione per $N$ volte.
#
# Ad ogni mossa misuro le grandezze caratteristiche e calcolo le medie suddividendo i dati in $50$ blocchi, ciascuno da $10^5$ punti. Per osservare l'andamento delle varie grandezze in funzione della temperatura eseguo la simulazione per $T \in [0.5, 2.0]$, campionando l'intervallo in $21$ punti, e rappresento la stima di valor medio e incertezza dell'ultimo blocco.

# %%
T_dat, u_M, err_u_M, c_M, err_c_M, x_M, err_x_M, m_M, err_m_M = np.loadtxt("Es06.1/risultati_Metropolis.dat", usecols=(0,1,2,3,4,5,6,7,8), delimiter=None, unpack=True)
T_dat, u_G, err_u_G, c_G, err_c_G, x_G, err_x_G, m_G, err_m_G = np.loadtxt("Es06.1/risultati_Gibbs.dat", usecols=(0,1,2,3,4,5,6,7,8), delimiter=None, unpack=True)


fig = plt.figure(figsize = (15,12))
plt.suptitle(' ')

plt.subplot(2, 2, 1)

plt.errorbar(T_dat, u_M, yerr=err_u_M, marker='o', ms=2, lw=1, label='Metropolis')
plt.errorbar(T_dat, u_G, yerr=err_u_G, marker='o', ms=2, lw=1, label='Gibbs')
plt.plot(T, e, lw=1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$U/N$', size=12)
plt.title('Energia interna', size=15)
plt.grid(True)
plt.legend()


plt.subplot(2, 2, 2)

plt.errorbar(T_dat, c_M, yerr=err_c_M, marker='o', ms=2, lw=1, label='Metropolis')
plt.errorbar(T_dat, c_G, yerr=err_c_G, marker='o', ms=2, lw=1, label='Gibbs')
plt.plot(T, heat, lw=1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$C$', size=12)
plt.title('Capacità termica', size=15)
plt.grid(True)
plt.legend()


plt.subplot(2, 2, 3)

plt.errorbar(T_dat, x_M, yerr=err_x_M, marker='o', ms=2, lw=1, label='Metropolis')
plt.errorbar(T_dat, x_G, yerr=err_x_G, marker='o', ms=2, lw=1, label='Gibbs')
plt.plot(T, X, lw=1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$\chi$', size=12)
plt.title('Suscettività', size=15)
plt.grid(True)
plt.legend()


plt.subplot(2, 2, 4)

plt.errorbar(T_dat, m_M, yerr=err_m_M, marker='o', ms=2, lw=1, label='Metropolis')
plt.errorbar(T_dat, m_G, yerr=err_m_G, marker='o', ms=2, lw=1, label='Gibbs')
plt.plot(T, M, lw=1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$M$', size=12)
plt.title('Magnetizzazione (h=0.02)', size=15)
plt.grid(True)
plt.legend()


plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# I risultati ottenuti seguono bene le curve teoriche e le barre d'errore sono troppo piccole per essere distinte. Inoltre non si vedono evidenti differenze tra l'algoritmo di Metropolis e di Gibbs.

# %%
fig = plt.figure(figsize = (15,12))
plt.suptitle('Differenze rispetto ai valori teorici', size=20)

h=0.02

e_teo=np.array([f_energy(temp) for temp in T_dat])
c_teo=np.array([f_heat(temp) for temp in T_dat])
x_teo=np.array([f_chi(temp) for temp in T_dat])
m_teo=np.array([f_mag(temp, h) for temp in T_dat])


plt.subplot(2, 2, 1)

plt.errorbar(T_dat, u_M-e_teo, yerr=err_u_M, marker='o', ms=3, elinewidth=1.5, ls='', label='Metropolis')
plt.errorbar(T_dat, u_G-e_teo, yerr=err_u_G, marker='o', ms=3, elinewidth=1.5, ls='', label='Gibbs')
plt.hlines(0, 0.4, 2.1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$\Delta U/N$', size=12)
plt.title('Energia interna', size=15)
plt.grid(True)
plt.legend()


plt.subplot(2, 2, 2)

plt.errorbar(T_dat, c_M-c_teo, yerr=err_c_M, marker='o', ms=3, elinewidth=1.5, ls='', label='Metropolis')
plt.errorbar(T_dat, c_G-c_teo, yerr=err_c_G, marker='o', ms=3, elinewidth=1.5, ls='', label='Gibbs')
plt.hlines(0, 0.4, 2.1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$\Delta C$', size=12)
plt.title('Capacità termica', size=15)
plt.grid(True)
plt.legend()


plt.subplot(2, 2, 3)

plt.errorbar(T_dat, x_M-x_teo, yerr=err_x_M, marker='o', ms=3, elinewidth=1.5, ls='', label='Metropolis')
plt.errorbar(T_dat, x_G-x_teo, yerr=err_x_G, marker='o', ms=3, elinewidth=1.5, ls='', label='Gibbs')
plt.hlines(0, 0.4, 2.1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$\Delta \chi$', size=12)
plt.title('Suscettività', size=15)
plt.grid(True)
plt.legend()


plt.subplot(2, 2, 4)

plt.errorbar(T_dat, m_M-m_teo, yerr=err_m_M, marker='o', ms=3, elinewidth=1.5, ls='', label='Metropolis')
plt.errorbar(T_dat, m_G-m_teo, yerr=err_m_G, marker='o', ms=3, elinewidth=1.5, ls='', label='Gibbs')
plt.hlines(0, 0.4, 2.1, label='Curva teorica')
plt.xlabel('T', size=12)
plt.ylabel('$\Delta M$', size=12)
plt.title('Magnetizzazione (h=0.02)', size=15)
plt.grid(True)
plt.legend()


plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# Dalle differenze tra i risultati e i valori teorici si osserva come entrambi gli algoritmi simulino bene il sistema a temperature alte, mentre a quelle più basse i risultati si discostano dal valore atteso e hanno incertezze maggiori.
#
# A temperature minori la probabilità di accettazione del Metropolis è significativamente bassa.
